# %% [markdown]
# # Data cleaning Red List Species 2016

# %% [markdown]
# 1. Import the relevant libraries

# %%
import pandas as pd
import numpy as np
import re
import math
import requests
import json
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
from datetime import datetime

# %% [markdown]
# 2. Loading the dataset

# %%
red016= pd.read_csv("data/Red_list_2016/data.csv", encoding = "ISO-8859-1")

# %%
red016.head()
# Out:
#    Index                    Country             Region   CC  Mammals  Birds  \
# 0      0                        NaN      North America  NaN       53     96
# 1      1                     Canada      North America  CAN       14     15
# 2      2  Saint Pierre and Miquelon      North America  SPM        4      4
# 3      3              United States      North America  USA       35     77
# 4      4                        NaN  Caribbean Islands  NaN       87    107
#
#    Reptiles  Amphibians  Fish  Molluscs  ...  A_TH_ED  A_EX  A_EW  A_CR  A_EN  \
# 0        43          57   295       306  ...       50     2     0     2    17
# 1         6           1    43         5  ...        0     0     0     0     0
# 2         0           0     3         0  ...        0     0     0     0     0
# 3        37          56   249       301  ...       50     2     0     2    17
# 4       209         182   847         6  ...        0     0     0     0     0
#
#    A_VU  A_NT  A_LC  A_DD  A_SP
# 0    38    34   210    14   318
# 1     1     2    43     0    46
# 2     0     0     0     0     ?
# 3    37    32   167    14   272
# 4     0     0     0     0     1
#
# [5 rows x 43 columns]

# %% [markdown]
# 3. Dropping the index

# %%
red016.drop("Index", axis=1, inplace= True)

# %% [markdown]
# 4. Rename columns

# %%
# Create a dictionary for the columns

dict_cols = ({"CC": "Country_code",
              "Mammals": "Mammals_CR+EN+VU",
              "T_EX":"extinct",
              "T_EW":"extinct_wild",
              "T_CR":"critically_endangered",
              "T_EN":"endangered",
              "T_VU":"vulnerable",
              "T_NT":"near_threatened",
              "T_DD":"data_deficient",
              "T_LC":"least_concern",
              "T_SP":"no_native_species",
              "M_ED":"no_endemic_species",
              "M_TH_ED":"no_endemics_red_list",
              "M_EX":"Mammals_extinct",
              "M_EW":"Mammals_extinct_wild",
              "M_CR":"mammals_critically_endangered",
              "M_EN":"mammals_endangered",
              "M_VU":"mammals_vulnerable",
              "M_NT":"mammals_near_threatened",
              "M_DD":"mammals_data_deficient",
              "M_LC":"mammals_least_concern",
              "M_SP":"mammals_no_native_species",
              "A_ED":"Amphibians_no_endemic_species",
              "A_TH_ED":"Amphi_no_endemics_red_list",
              "A_EX":"Amphi_extinct",
              "A_EW":"Amphi_extinct_wild",
              "A_CR":"Amphi_critically_endangered",
              "A_EN":"Amphi_endangered",
              "A_VU":"Amphi_vulnerable",
              "A_NT":"Amphi_near_threatened",
              "A_DD":"Amphi_data_deficient",
              "A_LC":"Amphi_least_concern",
              "A_SP":"Amphi_no_native_species", 
             })

# %%
# Rename columns

red016= red016.rename(columns = dict_cols)

# %%
indexNames = red016[red016["Country"].isna()].index

# Delete these row indexes from dataFrame
red016.drop(indexNames , inplace=True)

# %%
#Export to csv

red016.to_csv("data/data_clean.csv")

# %% [markdown]
# 5. Create a derived data set

# %%
df_regions = red016[["Region", "Mammals_CR+EN+VU", "Birds", "Reptiles", "Amphibians", "Fish", "Molluscs", "Other_Inverts"]].groupby("Region").sum()

# %%
df_regions.head()
# Out:
#                    Mammals_CR+EN+VU  Birds  Reptiles  Amphibians  Fish  \
# Region
# Antarctic                        10     33         4           0     7
# Caribbean Islands                87    107       209         182   847
# East Asia                       147    260        77         127   342
# Europe                          207    380        72          32   960
# Mesoamerica                     166    157       218         486   465
#
#                    Molluscs  Other_Inverts
# Region
# Antarctic                 0              0
# Caribbean Islands         6            311
# East Asia                50            345
# Europe                  879            789
# Mesoamerica              12            219

# %%
# transpose 
df_regions = df_regions.reset_index()
df_regions = df_regions.transpose().reset_index()
df_regions.head()
# Out:
#               index          0                  1          2       3  \
# 0            Region  Antarctic  Caribbean Islands  East Asia  Europe
# 1  Mammals_CR+EN+VU         10                 87        147     207
# 2             Birds         33                107        260     380
# 3          Reptiles          4                209         77      72
# 4        Amphibians          0                182        127      32
#
#              4             5              6           7        8  \
# 0  Mesoamerica  North Africa  North America  North Asia  Oceania
# 1          166            86             53          51      186
# 2          157            62             96          93      390
# 3          218            46             43          12      216
# 4          486             6             57           0       64
#
#                         9             10                  11  \
# 0  South & Southeast Asia  South America  Sub-Saharan Africa
# 1                     808            397                 936
# 2                     702            773                 915
# 3                     370            186                 447
# 4                     318            716                 402
#
#                     12
# 0  West & Central Asia
# 1                  272
# 2                  425
# 3                  157
# 4                   24

# %%
# Create a list with the names of columns and a dictionary with the desired names

cols = list(df_regions.iloc[0])

col_dic = {}

for i in range(13):
    col_dic[i] = cols[i+1]

# %%
# Rename columns

df = df_regions.rename(columns = {"index": "Species_group"})

df = df.rename(columns = col_dic)

# %%
# drop the first row

df = df.drop([0])

# %%
df.head()
# Out:
#       Species_group Antarctic Caribbean Islands East Asia Europe Mesoamerica  \
# 1  Mammals_CR+EN+VU        10                87       147    207         166
# 2             Birds        33               107       260    380         157
# 3          Reptiles         4               209        77     72         218
# 4        Amphibians         0               182       127     32         486
# 5              Fish         7               847       342    960         465
#
#   North Africa North America North Asia Oceania South & Southeast Asia  \
# 1           86            53         51     186                    808
# 2           62            96         93     390                    702
# 3           46            43         12     216                    370
# 4            6            57          0      64                    318
# 5          247           295         73     586                   1065
#
#   South America Sub-Saharan Africa West & Central Asia
# 1           397                936                 272
# 2           773                915                 425
# 3           186                447                 157
# 4           716                402                  24
# 5           541               2075                 621

# %%
# Export to csv

df.to_csv("data/species_group.csv")
