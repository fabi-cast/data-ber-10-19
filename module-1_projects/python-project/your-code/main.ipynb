# %%
# We will use the function sleep of module time to give a little more "suspense" during the game

import time

# drawings to use for graphic environment

logo = '''
                                                                                                                                                            
#######                                                                                                      
#        ####   ####    ##   #####  ######    ##### #    # ######    #####   ####   ####  #    #             
#       #      #    #  #  #  #    # #           #   #    # #         #    # #    # #    # ##  ##             
#####    ####  #      #    # #    # #####       #   ###### #####     #    # #    # #    # # ## #             
#            # #      ###### #####  #           #   #    # #         #####  #    # #    # #    #  
#       #    # #    # #    # #      #           #   #    # #         #   #  #    # #    # #    #  
#######  ####   ####  #    # #      ######      #   #    # ######    #    #  ####   ####  #    #  
                                                                                                             
'''

sofa = '''
 .-="""""""""""=-.
 | . . . . . . . |
 | .'.'.'.'.'.'. |   Couch
()_______________()
||_______________||
 W               W     

'''

def key_draw(letter):
    
    '''
    This function return a string that is a picture of a key with the name of the argument in uppercase
    
    '''
    
    letterb= letter.upper()
    return '''
     .--.
    /.-. '----------.    Key {}
    \'-' .--"--""-"-'     
     '--'
    '''.format(letterb)




piano_d = '''
  o    _______________
 /\_  _|             |
_\__`[_______________|   Piano 
] [ \, ][         ][

'''

queenbed_d = '''
   ||
   ||                   ||
||/||___                ||
|| /`   )____________||_/|
||/___ //_/_/_/_/_/_/||/ |     Queen Bed
||(___)/_/_/_/_/_/_/_||  |
||     |_|_|_|_|_|_|_|| /|
||     | | | | | | | ||/||
||~~~~~~~~~~~~~~~~~~~||
||                   ||    
'''

doublebed_d= '''
            ___
        ,-""___""-.
       .;""'| |`"":.
       || | | | | ||
       ||_|_|_|_|_||
      //          /|    Double bed
     /__         //|
 ,-""___""-.    //||
.;""'| |`"":.  //
||/| | | | || //
||_|_|_|_|_||//
||_________||/
||         ||     
''         ''
'''

dresser_d = '''
        ___________________
       (,_________________ )
       ||                 ||
       ||                 ||
       ||                 || 
       ||                 ||    Dresser
       ||                 || 
       ||                 ||
       ||_________________|| 
   .---('___________________) 
   |____     ________      _|
    |___| -o- |     |_| -o- |
    |___| -o- |     |_| -o- |     
        |_____|     |_|_____|      
'''



def door(letter) :
    
    '''
    This function return a string that is a picture of a door with the name of the argument in uppercase
    
    '''
    letterb =letter.upper()
    return '''          
       __________
      |  __  __  |
      | |  ||  | |
      | |  ||  | |
      | |__||__| |
      |  __  __()|  Door {}
      | |  ||  | |
      | |  ||  | |
      | |  ||  | |
      | |  ||  | |
      | |__||__| |
      |__________|

    '''.format(letterb)


table = '''
         ___________________
       /                    /
      /                    /|    Dining Table
     /____________________/ |
     |  |                 | |
     |  |                 | |
     |                    | 

'''

final = '''
 #####                                                  
#     #  ####  #    #  ####  #####    ##   #####  ####  
#       #    # ##   # #    # #    #  #  #    #   #      
#       #    # # #  # #      #    # #    #   #    ####  
#       #    # #  # # #  ### #####  ######   #        # 
#     # #    # #   ## #    # #   #  #    #   #   #    # 
 #####   ####  #    #  ####  #    # #    #   #    #### 
'''    
    
# define rooms and items

door_a = {
    "name": "door a",
    "type": "door",
    "image": door('a')
    
}

door_b = {
    "name": "door b",
    "type": "door",
    "image": door('b')
    
}

door_c = {
    "name": "door c",
    "type": "door",
    "image": door('c')
    
}

door_d = {
    "name": "door d",
    "type": "door",
    "image": door("d")

}

key_a = {
    "name": "key for door a",
    "type": "key",
    "target": door_a,
    "image": key_draw("a")
}

key_b = {
    "name": "key for door b",
    "type": "key",
    "target": door_b,
    "image": key_draw("b")

}

key_c = {
    "name": "key for door c",
    "type": "key",
    "target": door_c,
    "image": key_draw("c")
}

key_d = {
    "name": "key for door d",
    "type": "key",
    "target": door_d,
    "image": key_draw("d")
}



couch = {
    "name": "couch",
    "type": "furniture",
    "image": sofa    
}

piano = {
    "name": "piano",
    "type": "furniture",
    "image": piano_d    
}

queen_bed={
    "name": "queen bed",
    "type": "furniture",
    "image": queenbed_d    

}

double_bed={
    "name": "double bed",
    "type": "furniture",
    "image": doublebed_d    

}

dresser={
    "name": "dresser",
    "type": "furniture",
    "image": dresser_d    
    
}

dinning_table={
    "name": "dining table",
    "type": "furniture",
    "image": table
}

game_room = {
    "name": "game room",
    "type": "room"
}

bedroom1 = {
    "name": "bedroom 1",
    "type": "room"
}

bedroom2 = {
    "name": "bedroom 2",
    "type": "room"
}

living_room = {
    "name": "living room",
    "type": "room"
}

outside = {
  "name": "outside"
}


all_rooms = [game_room, outside, bedroom1, bedroom2, living_room]

all_doors = [door_a, door_b, door_c, door_d]

# define which items/rooms are related

object_relations = {
    "game room": [couch, piano, door_a],
    "piano": [key_a],
    "outside": [door_d],
    "bedroom 1": [queen_bed, door_a, door_b, door_c],
    "queen bed": [key_b],
    "door a": [game_room, bedroom1],
    "door b": [bedroom1, bedroom2],
    "door c": [bedroom1, living_room],
    "door d": [living_room, outside],
    "bedroom 2": [double_bed, dresser, door_b],
    "double bed": [key_c],
    "dresser": [key_d],
    "living room": [dinning_table, door_c, door_d],
}

# %%
# define game state. Do not directly change this dict. 
# Instead, when a new game starts, make a copy of this
# dict and use the copy to store gameplay state. This 
# way you can replay the game multiple times.

INIT_GAME_STATE = {
    "current_room": game_room,
    "keys_collected": [],
    "target_room": outside
}

# %%
def linebreak():
    """
    Print a line break
    """
    print("\n\n")

def start_game():
    
    """
    Start the game
    """
    
    global name 
    name = input("What is your name friend?")
    linebreak()
    time.sleep(2)
    print("Bad news %s." % name)
    time.sleep(1)    
    
    print(logo)
    
    print('''
    You wake up on a couch and find yourself in a strange house with no windows
    which you have never been before. You don't remember why you are here and what had happened
    before. You feel some unknown danger is approaching and you must get out of the house, NOW!
    ''')
    
    linebreak()
    
    time.sleep(1)
    
    play_room(game_state["current_room"])


def play_room(room):
    """
    Play a room. First check if the room being played is the target room.
    If it is, the game will end with success. Otherwise, let player either 
    explore (list all items in this room) or inspect an item found here.
    """
    game_state["current_room"] = room
    if(game_state["current_room"] == game_state["target_room"]):
        print(key_draw('d'))
        time.sleep(3)
        
        print(final)
        
        time.sleep(1)

        print("{}, you escaped the room!".format(name))
    else:
        print("You are now in " + room["name"])
        intended_action = input("What would you like to do? Type 'explore' or 'inspect'?").strip()
        if intended_action == "explore":
            explore_room(room)
            play_room(room)
        elif intended_action == "inspect":
            inspect_item(input("What would you like to inspect?").strip())
        else:
            print("Please type 'explore' or 'inspect'.")
            play_room(room)
        linebreak()

def explore_room(room):
    """
    Explore a room. List all items belonging to this room.
    """
    items = [i["name"] for i in object_relations[room["name"]]]
    print("You explore the room.") 
    linebreak()
    print("You explore the room. This is " + room["name"] + ". You find " + ", ".join(items))
    for i in object_relations[room["name"]]:
        print(i["image"])
    

def get_next_room_of_door(door, current_room):
    """
    From object_relations, find the two rooms connected to the given door.
    Return the room that is not the current_room.
    """
    connected_rooms = object_relations[door["name"]]
    for room in connected_rooms:
        if(not current_room == room):
            return room

def inspect_item(item_name):
    """
    Inspect an item which can be a door or furniture.
    First make sure the intended item belongs to the current room.
    Then check if the item is a door. Tell player if key hasn't been 
    collected yet. Otherwise ask player if they want to go to the next
    room. If the item is not a door, then check if it contains keys.
    Collect the key if found and update the game state. At the end,
    play either the current or the next room depending on the game state
    to keep playing.
    """
    current_room = game_state["current_room"]
    next_room = ""
    output = None
    
    for item in object_relations[current_room["name"]]:
        if(item["name"] == item_name):
            output = "You inspect " + item_name + ". "
            if(item["type"] == "door"):
                have_key = False
                for key in game_state["keys_collected"]:
                    if(key["target"] == item):
                        have_key = True
                if(have_key):
                    output += "You unlock it with a key you have."
                    next_room = get_next_room_of_door(item, current_room)
                else:
                    output += "It is locked but you don't have the key."
            else:
                if(item["name"] in object_relations and len(object_relations[item["name"]])>0):
                    item_found = object_relations[item["name"]].pop()
                    game_state["keys_collected"].append(item_found)
                    output += "You find " + item_found["name"] + "."
                    print(item_found["image"])
                    
                else:
                    output += "There isn't anything interesting about it."
            print(output)
            break

    if(output is None):
        print("The item you requested is not found in the current room.")
    
    if(next_room and input("Do you want to go to the next room? Enter 'yes' or 'no'").strip() == 'yes'):
        play_room(next_room)
    else:
        play_room(current_room)

# %%
game_state = INIT_GAME_STATE.copy()

# %%
start_game()
# Out:
# What is your name friend? Hector
# Bad news Hector.
#
#
# #######
# #        ####   ####    ##   #####  ######    ##### #    # ######    #####   ####   ####  #    #
# #       #      #    #  #  #  #    # #           #   #    # #         #    # #    # #    # ##  ##
# #####    ####  #      #    # #    # #####       #   ###### #####     #    # #    # #    # # ## #
# #            # #      ###### #####  #           #   #    # #         #####  #    # #    # #    #
# #       #    # #    # #    # #      #           #   #    # #         #   #  #    # #    # #    #
# #######  ####   ####  #    # #      ######      #   #    # ######    #    #  ####   ####  #    #
#
#
#
#     You wake up on a couch and find yourself in a strange house with no windows
#     which you have never been before. You don't remember why you are here and what had happened
#     before. You feel some unknown danger is approaching and you must get out of the house, NOW!
#
#
#
#
# You are now in game room
# ...
